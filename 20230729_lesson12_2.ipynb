# %%
import random
import matplotlib.pyplot as plt

days = list(range(1,32))


#celsius = []
#for _ in range(31):
#    celsius.append(round(random.uniform(25,45),ndigits=2))

#list comprehension
#完整判斷式
#celsius = [round(random.uniform(25,45),ndigits=2) for x in range(31) if x >15]

celsius = [round(random.uniform(25,45),ndigits=2) for x in range(31)]
figure = plt.figure(figsize=(8,4))
axes = figure.add_subplot(1,1,1)
axes.plot(days,celsius,'r--.')
axes.grid(axis='y')
axes.set_xticks(days)
plt.show()

# %%
#list無法進行數值運算
list1 = [1, 2, 3]
list2 = [5, 6, 7]
list1 + list2 , list1 * 3
# Out:
# ([1, 2, 3, 5, 6, 7], [1, 2, 3, 1, 2, 3, 1, 2, 3])

# %%
import numpy as np

#數列的運算:numpy
np1 = np.array([1, 2, 3])
np2 = np.array([5, 6, 7])
np1 + np2, np1 * 10
# Out:
# (array([ 6,  8, 10]), array([10, 20, 30]))
