# %%
import numpy as np
n1=np.random.randint(50,100,size=(10,))
n1
# Out:
# array([68, 80, 82, 82, 58, 79, 68, 89, 81, 56])

# %%
import numpy as np
import pandas as pd

#將numpy(array)加上欄列(index)資訊: pandas.Series
n1 = np.random.randint(200,300,size=(10,))
s1 = pd.Series(data=n1,index=[f"學生{i+1}" for i in range(10)])
display(s1+100)
display(s1.values)
display(s1.index)
# Out:
# 學生1     366
# 學生2     375
# 學生3     394
# 學生4     397
# 學生5     359
# 學生6     313
# 學生7     382
# 學生8     334
# 學生9     396
# 學生10    346
# dtype: int64
# array([266, 275, 294, 297, 259, 213, 282, 234, 296, 246])
# Index(['學生1', '學生2', '學生3', '學生4', '學生5', '學生6', '學生7', '學生8', '學生9', '學生10'], dtype='object')

# %%
import requests
import pandas as pd

# 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
times = 1
cnames = []
for x in range(times):
    url = 'http://www.richyli.com/name/index.asp'
    r = requests.get(url)
    r.encoding = 'big5'
    
    # 將網頁中的資料以分行的方式存成文字檔
    result = r.text.splitlines()
    
    # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
    char_index = result[114].rfind("、")
    temp = result[114][:char_index]
    
    # 將temp的100筆姓名新增到cnames中
    cnames.append(temp)

# 將每100筆姓名的list加一個「、」，再組合成字串存到my_names中
my_names = "、".join(str(x) for x in cnames)
print(my_names)
# Out:
# 謝嘉元、陳宗翰、李書瑋、王雅達、李冰剛、許家文、吳昌宸、趙允仁、林吟月、林于倫、林家平、沈亭雲、張耀城、陳俐伯、邰惠娟、錢儒星、張美慧、王怡富、蔡明珠、吳惠玲、李坤凡、林志心、陳冠伶、吳文苓、洪恆淑、陳信芸、陳詩彬、湯怡婷、蔡佳東、謝依康、游萱妹、吳嘉侑、洪亞妤、謝怡君、蕭嘉雯、謝美珠、陳莉汝、高惠雯、吳佩杰、夏怡雯、賴銘諭、羅詩堯、徐志成、連義孝、丁則貴、林詩弘、朱曉銘、吳淑華、王琪禎、劉乃薇、陳建彰、張秀斌、周凱琳、汪建宇、邱于庭、王冠華、張志偉、林家侑、姜偉天、林姿義、林佐依、蔡雅惠、江佳儒、林佳樺、吳若杰、蔣旭水、李春年、施惠茹、沈靜如、許冠良、林立泉、胡雅嵐、陳逸均、陳玫仲、林廷珮、李為柏、劉采志、張佳儀、劉佳君、駱怡君、黃又忠、張寧書、劉羿玫、李台義、楊伊州、陳欣怡、李向旺、陳怡君、李希屏、李玟恬、李雅婷、黃千夫、戴淑美、黃玉毓、陳雅蓁、張彥志、蔡欣宜、謝雅君、謝文宏、李緯季

# %%
import requests
def getNames(num):
    times = 1
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    print(type(cnames[0]))
    names = cnames[0].split('、')
    return names[:num]


# 竇佩珊  83  57  99  64  52  355
# 楊智劭  56  50  63  93  69  331
# 李靜如  98  76  84  69  72  399
# 謝依婷  51  72  72  55  53  303
# 曹先修  60  63  70  58  68  319
# 郭怡汝  69  94  57  99  84  403
# 王柏鈞  54  91  83  97  82  407
# 林佳慧  63  51  51  85  96  346
# 吳嘉意  97  53  69  59  61  339
# 劉家華  78  93  97  85  78  431
# 馬向羽  98  51  74  79  85  387
# 解威雯  80  80  93  77  60  390
# 周怡珊  96  75  90  92  76  429
# 吳昭峰  95  57  80  51  89  372
# 程俊杰  87  58  94  69  56  364
# 賴曼恭  57  71  71  55  77  331
# 黃偉傑  51  94  90  85  95  415
# 張家榮  78  58  93  54  81  364
# 戴琬婷  86  68  52  94  59  359
# 簡進杰  88  62  76  86  52  364
# 張世彥  92  76  63  64  87  382
# 吳美君  55  66  98  87  90  396
# 姜莉娥  89  78  96  72  77  412
# 駱育瑋  94  87  60  90  77  408
# 張美念  70  75  55  88  78  366
# 蔡佩全  66  74  89  77  60  366
# 黃紫皓  64  64  83  56  94  361
# 林逸昌  54  66  83  76  71  350
# 黃睿豪  98  65  73  61  69  366
# 鄭鈞芬  87  57  90  71  67  372
# 李國璇  77  75  65  82  50  349

# %%
#使用'、'符號，連結3個陣列元素
names_str = "、".join(names)
names_list = names_str.split("、") #有299筆的list
newLine_name = "\n".join(names_list)  #有換行符號的字串
print(newLine_name)
# Out:
# 江維哲
# 邱仰弘
# 郭純杰
# 鄧建良
# 黃凱琦
# 葉韻娥
# 張俊緯
# 蔡雅坤
# 吳仁璇
# 鄧勇琪
# 胡玟君
# 王幸瑋
# 張定中
# 蒯雅惠
# 吳建勳
# 王淑書
# 黃佳琪
# 施淑貞
# 陳倩胤
# 竇佩珊
# 楊智劭
# 李靜如
# 謝依婷
# 曹先修
# 郭怡汝
# 王柏鈞
# 林佳慧
# 吳嘉意
# 劉家華
# 馬向羽
# 解威雯
# 周怡珊
# 吳昭峰
# 程俊杰
# 賴曼恭
# 黃偉傑
# 張家榮
# 戴琬婷
# 簡進杰
# 張世彥
# 吳美君
# 姜莉娥
# 駱育瑋
# 張美念
# 蔡佩全
# 黃紫皓
# 林逸昌
# 黃睿豪
# 鄭鈞芬
# 李國璇
# 簡兆良
# 王堯孜
# 滕馨儀
# 樂怡君
# 方耀明
# 許冠宇
# 陳昭羽
# 黃啟湖
# 邰彥翔
# 黃淑珍
# 陳信仲
# 倪思潔
# 周志利
# 富冠霖
# 王惠美
# 李宜城
# 賴怡昇
# 王維禾
# 阮佳蓉
# 蔡文其
# 韓旭芬
# 陳俊伯
# 陳姿君
# 李婉孜
# 陳逸茂
# 黃名菁
# 陳肇威
# 許淑娟
# 吳怡伶
# 蔡智谷
# 劉彥琳
# 蔡奕一
# 趙家華
# 林耀德
# 陳雅玲
# 關百毓
# 平冠良
# 黃介屏
# 陳碧沛
# 許文凌
# 李友勇
# 鄭志忠
# 張瑋毓
# 楊惠珠
# 謝偉倫
# 李鳳�琚B李建勳
# 汪政翰
# 趙靜如
# 駱宜臻

# %%
with open("names.csv",mode="w",encoding='utf-8',newline="") as file:
    file.write(newLine_name)
